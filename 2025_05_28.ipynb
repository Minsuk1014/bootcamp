# %% [markdown]
# # 이자율을 계산해보자.

# %%
import math
e = 0
for x in range(1000):
    t = 1 / math.factorial(x)
    e += t 
    if x % 100 == 0: print(e)
# Out:
# 1.0
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455
# 2.7182818284590455

# %% [markdown]
# # 평균
# 총 합계의 수 / 합계의 갯수
#
# # 중앙값
# 값의 중앙값 순서대로 나열 후 중간값을 확인 (홀수인 경우 가운데, 짝수인 경우 (짝수 중앙값에 -1 +1 /2)
# --> 항상 평균과 중앙값을 동시에 봐야한다.
#
# # 편차
# 각각의 값에 평균값을 뻄
#
# # 분산 var
# 표준편차의 제곱
#
# # 표준편차 std
# 편차들을 제곱해서 평균낸 후 루트
# val = -3 -2 0 5 5
# mean = 1  1 1 1 1
# 분산 = -4 -3 -1 4 4
# var = 16 9 1 16 16
# std = 58/5 ~ sqrt(11) -> 3
#
# # 환경 맞추기
# """
# 목록 보여주기
# pip list --format=freeze
#
# 내 라이브러리 저장
# requirements.txt 에 저장 ->
# pip list --format=freeze > requiremnets.txt
# 라이브러리 설치
# pip install -r requiremnets.txt
#
# 환경 들어갈 때 . ./streamlit/bin/activate 에서 .(띄어쓰기). --> 처음 .은 source와 같다.
#
# pypi.org -> 파이썬 라이브러리 관리 사이트
#
#
# 의존성 파일 < 리스트에 적은 파일 우선
#
#
#
# ---------
# 리눅스 terminal에 python과 ipython이 있는데 다음과 같다.
# 쥬피터는 ipython : 대화형 파이썬이다. 개발용보단, 분석형
# 보통은 python
# ---------
# chmod {권한접근숫자} {파일}-> 권한을 바꾸는

# %%
import requests

url = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"


payload={"bld":"dbms/MDC/STAT/standard/MDCSTAT01901",
"locale":"ko_KR",
"mktId":"ALL",
"share":"1",
"csvxls_isNo":"false",}


request_headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Connection": "keep-alive",
    "Content-Length": "88",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Host": "data.krx.co.kr",
    "Origin": "http://data.krx.co.kr",
    "Referer": "http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201020201",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest"
}
"""
headers에 User-Agent만 넣으면 안돼?? 
--> 애초에 넣는 이유가 사람인걸 모르게 하기 위해서임
headers를 확인하는데, 보안이 약한건 User-Agent정도만 해도 넘어가는데
이건 그게 아니라는거
"""
r= requests.post(url, data=payload, headers=request_headers)

r.json().keys()

print(r.text)
data = r.json()['OutBlock_1']
# Out:
# {"OutBlock_1":[{"ISU_CD":"KR7098120009","ISU_SRT_CD":"098120","ISU_NM":"(주)마이크로컨텍솔루션","ISU_ABBRV":"마이크로컨텍솔","ISU_ENG_NM":"Micro Contact Solution Co.,Ltd.","LIST_DD":"2008/09/23","MKT_TP_NM":"KOSDAQ","SECUGRP_NM":"주권","SECT_TP_NM":"중견기업부","KIND_STKCERT_TP_NM":"보통주","PARVAL":"500","LIST_SHRS":"8,312,766"},{"ISU_CD":"KR7009520008","ISU_SRT_CD":"009520","ISU_NM":"(주)포스코엠텍","ISU_ABBRV":"포스코엠텍","ISU_ENG_NM":"POSCO M-TECH CO.,LTD.","LIST_DD":"1997/11/10","MKT_TP_NM":"KOSDAQ GLOBAL","SECUGRP_NM":"주권","SECT_TP_NM":"우량기업부","KIND_STKCERT_TP_NM":"보통주","PARVAL":"500","LIST_SHRS":"41,642,703"},{"ISU_CD":"KR7095570008","ISU_SRT_CD":"095570","ISU_NM":"AJ네트웍스보통주","ISU_ABBRV":"AJ네트웍스","ISU_ENG_NM":"AJ Networks Co.,Ltd.","LIST_DD":"2015/08/21","MKT_TP_NM":"KOSPI","SECUGRP_NM":"주권","SECT_TP_NM":"","KIND_STKCERT_TP_NM":"보통주","PARVAL":"1,000","LIST_SHRS":"45,252,759"},{"ISU_CD":"KR7006840003","ISU_SRT_CD":"006840","ISU_NM":"AK홀딩스보통주","ISU_ABBRV":"AK홀딩스","ISU_ENG_NM":"AK Holdings, Inc.","LIST_DD":"1999/08/
# ...

# %%
target = 'LG전자'
target_code = []
for x in data:
    if x['ISU_ABBRV'].find(f"{target}") > -1:
        target_code.append(x)

# %%
for y in target_code:
    if y['ISU_ABBRV'].find(target + "우") == -1:
        print(y['ISU_SRT_CD'])
# Out:
# 066570

# %%
[y['ISU_SRT_CD'] for y in [ x for x in data if x['ISU_ABBRV'].find(f"{target}") > -1] if y['ISU_ABBRV'].find(target + '우') == -1]
# Out:
# ['066570']
